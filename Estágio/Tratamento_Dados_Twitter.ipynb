# %% [markdown]
# <a href="https://colab.research.google.com/github/JeanCarloTS/Machine-Learning-Projects/blob/main/Est%C3%A1gio/Tratamento_Dados_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Bibliotecas**

# %%
import pandas as pd                   # manipulação de base de dados
import numpy as np                    # manipulação numérica
import seaborn as sns                 # manipulaçõa gráfica
import matplotlib.pyplot as plt       # manipulação gráfica

# %% [markdown]
# # **2. Importação dos dados (Drive)**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Gerando o Data Frame que vai carregar os dados importados
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Estágio - IMT & NPL Brasil/Primeira Semana_cnnbrasil_tweets.csv', error_bad_lines=False)
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Estágio - IMT & NPL Brasil/Primeira Semana_estadao_tweets.csv', error_bad_lines=False)
df3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Estágio - IMT & NPL Brasil/Primeira Semana_folha_tweets.csv', error_bad_lines=False)
df4 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Estágio - IMT & NPL Brasil/Primeira Semana_jornaldobrasil_tweets.csv', error_bad_lines=False)
df5 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Estágio - IMT & NPL Brasil/Primeira Semana_nexojornal_tweets.csv', error_bad_lines=False)

# %%
df = df1.copy()
df = pd.merge(df, df2, how='outer')
df = pd.merge(df, df3, how='outer')
df = pd.merge(df, df4, how='outer')
df = pd.merge(df, df5, how='outer')

# %%
df
# Out:
#                         id           created_at  ... in reply to  retweeted
# 0      1396860868957130755  2021-05-24 16:09:18  ...         NaN      False
# 1      1396860373601427460  2021-05-24 16:07:20  ...         NaN      False
# 2      1396860123868446720  2021-05-24 16:06:20  ...         NaN      False
# 3      1396860068935749632  2021-05-24 16:06:07  ...         NaN      False
# 4      1396858874125295617  2021-05-24 16:01:22  ...         NaN      False
# ...                    ...                  ...  ...         ...        ...
# 16235  1343270711117414400  2020-12-27 19:01:08  ...         NaN      False
# 16236  1343255583504412672  2020-12-27 18:01:02  ...         NaN      False
# 16237  1343240634199638017  2020-12-27 17:01:38  ...         NaN      False
# 16238  1343225525003808768  2020-12-27 16:01:35  ...         NaN      False
# 16239  1343210172970360838  2020-12-27 15:00:35  ...         NaN      False
#
# [16240 rows x 6 columns]

# %% [markdown]
# ## **2.1 Reconhecimento dos dados (Drive)**

# %%
df.columns                            # Informação de quais são as colunas do Data Frame, e também, como estão nomeadas
# Out:
# Index(['id', 'created_at', 'text', 'likes', 'in reply to', 'retweeted'], dtype='object')

# %%
df['text'][16239]
# Out:
# 'Seleção #MaisLidasDoNexo entre os assinantes em 2020. Este conteúdo está com #acessolivre por tempo limitado. Aprov… https://t.co/AqiKEs3r0y'

# %%
df.describe()                         # Informações sobre as colunas númericas apenas
# Out:
#                  id         likes
# count  1.624000e+04  16240.000000
# mean   1.386219e+18    119.514039
# std    1.437718e+16    626.234042
# min    1.343210e+18      0.000000
# 25%    1.378539e+18      0.000000
# 50%    1.393203e+18     26.000000
# 75%    1.395813e+18     74.000000
# max    1.399359e+18  23462.000000

# %% [markdown]
# # **3. Pre-processamento dos dados**

# %% [markdown]
# ## **3.1 Utilizando artifícios de programação**

# %%
### Copiando o Data Frame para poder fazer manipulações sem alterá-lo

df_copy = df.copy()
df_copy.head()
# Out:
#                     id           created_at  ... in reply to  retweeted
# 0  1396860868957130755  2021-05-24 16:09:18  ...         NaN      False
# 1  1396860373601427460  2021-05-24 16:07:20  ...         NaN      False
# 2  1396860123868446720  2021-05-24 16:06:20  ...         NaN      False
# 3  1396860068935749632  2021-05-24 16:06:07  ...         NaN      False
# 4  1396858874125295617  2021-05-24 16:01:22  ...         NaN      False
#
# [5 rows x 6 columns]

# %% [markdown]
# ### **3.1.1 Retirar: links, emails e etc**

# %%
### Uma vez que foi analisada a presença de links nos textos, eles não são interessantes, portanto serão retirados 

import re                                                                                 # Modulo de Regular Expressions

df_copy['text'] = df_copy['text'].apply(lambda x: re.sub(r"(?:\@|https?\://)\S+", "", x)) # Regular expression que retira links|e-mails  

print(df['text'][16239])
print(df_copy['text'][16239])
# Out:
# Seleção #MaisLidasDoNexo entre os assinantes em 2020. Este conteúdo está com #acessolivre por tempo limitado. Aprov… https://t.co/AqiKEs3r0y
# Seleção #MaisLidasDoNexo entre os assinantes em 2020. Este conteúdo está com #acessolivre por tempo limitado. Aprov…

# %% [markdown]
# ### **3.1.2 Retirar: quebras de linhas e colchetes**

# %%
i = 0
for i in range(len(df['text'])):
  texto = df_copy['text'][i]
  texto = texto.rstrip('\n')
  texto = texto.replace("[", "")
  texto = texto.replace("]", "")
  df_copy['text'][i] = texto

print(df['text'][16238])
print(df_copy['text'][16238])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# [opinião] ‘O termo empreendedorismo nada mais é do que a expressão invertida da eliminação de qualquer rede de prot… https://t.co/ycvsClSmTI
# opinião ‘O termo empreendedorismo nada mais é do que a expressão invertida da eliminação de qualquer rede de prot…

# %% [markdown]
# ### **3.1.3 Retirar: datas, numeros e informações numéricas de maneira geral**

# %%
import re          # Modulo de Regular Expressions

# Regular expression que retira informações numéricas
df_copy['text'] = df_copy['text'].apply(lambda x: re.sub(r"[0-9]", "", x))

# %%
### Note o 24, agora não existe mais!

print(df['text'][1])
print(df_copy['text'][1])
# Out:
# O novo presidente do Equador, Guillermo Lasso, foi empossado nesta segunda-feira (24) em na capital Quito. A cerimô… https://t.co/0BvvUmeO1x
# O novo presidente do Equador, Guillermo Lasso, foi empossado nesta segunda-feira () em na capital Quito. A cerimô…

# %% [markdown]
# ### **3.1.4 Retirar: caracteres especiais**

# %%
import string
punctuation_list = [' ']
for punc in string.punctuation:
  punctuation_list.append(punc)
print("Os caracteres especiais são: ",string.punctuation)
# Out:
# Os caracteres especiais são:  !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
import re          # Modulo de Regular Expressions

# Regular expression que retira caracteres especiais
df_copy['text'] = df_copy['text'].apply(lambda x: re.sub(r"[!#$%&'""()*+,-./:;<=>?@\‘^_`{|}~]", "", x))

# %%
### Note que no 24 havia parentese, agora não há mais!

print(df['text'][16238])
print(df_copy['text'][16238])
# Out:
# [opinião] ‘O termo empreendedorismo nada mais é do que a expressão invertida da eliminação de qualquer rede de prot… https://t.co/ycvsClSmTI
# opinião O termo empreendedorismo nada mais é do que a expressão invertida da eliminação de qualquer rede de prot…

# %% [markdown]
# ### **3.1.6 Analisar: lógica Fuzzy**

# %% [markdown]
# ### **3.1.5 Corrigir erros de ortografia**

# %% [markdown]
# ## **3.2 Testes utiliziando bibliotecas**

# %% [markdown]
# ### **3.2.1 CountVectorizer**

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html

# %%
from sklearn.feature_extraction.text import CountVectorizer

### Universo de palavras - corpus

corpus      =  np.array(df_final['text'])                 # Gerando uma sequência de textos(conteúdo dos Tweets). Isso é necessário para o Vectorizer

### Criação da funcionalidade

vectorizer_cv  =   CountVectorizer()                  
countvec       =   vectorizer_cv.fit_transform(corpus)    # Numera quantas vezes uma palavra aprendida (após analisar toda a coluna) aparece em uma instância (mensagem)
array_vec      =   countvec.toarray()                  # Matriz de arrays com número de aparições de uma palavra aprendida em uma determinada mensagem
words_lrnd     =   vectorizer_cv.get_feature_names()      # Palavras aprendidas com os dados 

print(words_lrnd[9532:9540])                        # Amostra de algumas palavras aprendidas
# Out:
# ['favoravelmente', 'favorece', 'favorecer', 'favoreceram', 'favorecerem', 'favoreceria', 'favoreça', 'favoritas']

# %%
### Amostra do conteúdo passado como texto.
### Nota-se que junto aos textos são passados links, possivelmente e-mails.
df['text'][0]
# Out:
# 'Tremores de terra sacudiram Goma, na República Democrática do Congo, nesta segunda-feira (24), assustando moradores… https://t.co/OhCimwW6tq'

# %%
print(vectorizer_cv.vocabulary_)       # Apresenta um dicionário com as palavras e o numero delas dentro do vocabulário 

print("O número de aparições da palavra 'tremores' dentro dessa mensagem é: {}".format(array_vec[0][22033]))
# Out:
# {'tremores': 22034, 'de': 5990, 'terra': 21489, 'sacudiram': 19901, 'goma': 10681, 'na': 15065, 'república': 19235, 'democrática': 6235, 'do': 7323, 'congo': 4935, 'nesta': 15292, 'segundafeira': 20194, 'assustando': 1908, 'moradores': 14752, 'novo': 15503, 'presidente': 17518, 'equador': 8301, 'guillermo': 10913, 'lasso': 13055, 'foi': 9962, 'empossado': 7906, 'em': 7806, 'capital': 3545, 'quito': 18388, 'cerimô': 3911, 'novos': 15504, 'dados': 5907, 'sobre': 20620, 'pesquisadores': 16800, 'wuhan': 23250, 'aumentam': 2148, 'debate': 5995, 'origens': 15944, 'da': 5900, 'covid': 5541, 'rt': 19803, 'ericsson': 8335, 'disse': 7203, 'que': 18297, 'pode': 17054, 'obter': 15626, 'uma': 22320, 'fatia': 9509, 'menor': 14289, 'no': 15380, 'lançamento': 13026, 'china': 4057, 'sua': 20876, 'participação': 16314, 'mercado': 14325, 'infra': 11953, 'aeroportos': 489, 'devem': 6894, 'ser': 20340, 'foco': 9948, 'para': 16191, 'conter': 5155, 'variante': 22569, 'índia': 23432, 'diz': 7303, 'infectologista': 11890, 'voltado': 23049, 'os': 15969, 'pequenos': 16607, 'negócios': 15263, 'microcrédito': 14429, 'um': 22319, 'tipo': 21630, 'empréstimo': 7939, 'oferece': 15710, 'vantagens': 22549, 'outros': 16004, 'não': 15539, 'têm': 22255, 'creditas': 5580, 'resolveu': 19301, 'fazer': 9554, 'grande': 10772, 'aposta': 1468, 'fora': 9994, 'área': 23390, 'produtos': 17740


# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

# %%
### TfidfVectorizer é melhor para datasets maiores(muito grandes), além disso possui mais features para stop_words, lowercase, frequency e etc.
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer_tf   =   TfidfVectorizer(min_df=1)
tfidfvec        =   vectorizer_tf.fit_transform(corpus)   # Contabiliza a frequencia de uma palavra dentro de uma mensagem em relação a quantas aparições no total ela tem
array_vec       =   tfidfvec.toarray()                    # Matriz de arrays com as frequências de uma palavra aprendida em uma determinada mensagem
words_lrnd2     =   vectorizer_tf.get_feature_names()     # Palavras aprendidas com os dados 

print(words_lrnd2[9532:9540])
# Out:
# ['favoravelmente', 'favorece', 'favorecer', 'favoreceram', 'favorecerem', 'favoreceria', 'favoreça', 'favoritas']

# %%
print(vectorizer_tf.vocabulary_)       # Apresenta um dicionário com as palavras e o numero delas dentro do vocabulário 

print("A frequência de aparições da palavra 'tremores' dentro dessa mensagem é: {}%".format(round(100*(array_vec[0][22033]),2)))
# Out:
# {'tremores': 22034, 'de': 5990, 'terra': 21489, 'sacudiram': 19901, 'goma': 10681, 'na': 15065, 'república': 19235, 'democrática': 6235, 'do': 7323, 'congo': 4935, 'nesta': 15292, 'segundafeira': 20194, 'assustando': 1908, 'moradores': 14752, 'novo': 15503, 'presidente': 17518, 'equador': 8301, 'guillermo': 10913, 'lasso': 13055, 'foi': 9962, 'empossado': 7906, 'em': 7806, 'capital': 3545, 'quito': 18388, 'cerimô': 3911, 'novos': 15504, 'dados': 5907, 'sobre': 20620, 'pesquisadores': 16800, 'wuhan': 23250, 'aumentam': 2148, 'debate': 5995, 'origens': 15944, 'da': 5900, 'covid': 5541, 'rt': 19803, 'ericsson': 8335, 'disse': 7203, 'que': 18297, 'pode': 17054, 'obter': 15626, 'uma': 22320, 'fatia': 9509, 'menor': 14289, 'no': 15380, 'lançamento': 13026, 'china': 4057, 'sua': 20876, 'participação': 16314, 'mercado': 14325, 'infra': 11953, 'aeroportos': 489, 'devem': 6894, 'ser': 20340, 'foco': 9948, 'para': 16191, 'conter': 5155, 'variante': 22569, 'índia': 23432, 'diz': 7303, 'infectologista': 11890, 'voltado': 23049, 'os': 15969, 'pequenos': 16607, 'negócios': 15263, 'microcrédito': 14429, 'um': 22319, 'tipo': 21630, 'empréstimo': 7939, 'oferece': 15710, 'vantagens': 22549, 'outros': 16004, 'não': 15539, 'têm': 22255, 'creditas': 5580, 'resolveu': 19301, 'fazer': 9554, 'grande': 10772, 'aposta': 1468, 'fora': 9994, 'área': 23390, 'produtos': 17740, 'financeiros': 9805, 'injetando': 12003, 'milhões': 14472, 'fabrica': 9334, 'banco': 2442, 'coreia': 5398, 'sul': 20983, 'informou': 11951, 'busca': 3226, 'empresa': 7926, 'tecnologia': 21331, 'desenvolver': 6581, 'seu': 20400, 'projeto': 17818, 'moeda': 14665, 
# %% [markdown]
# **- Retira pontuações e espaços**

# %% [markdown]
# **- Retira palavras com frequencia muito alta ou muito baixa**

# %%
### Analisa as mensagens (documentos) exclui todas as palavras que aparecem em menos de 2 documentos
### Baixa frequência

vectors1       = CountVectorizer(min_df = 2)              # Se numero inteiro, aparentemente é considerada a contagem da palavra, já se for numero entre 0 e 1,
                                                          # a porcentagem de documentos em que a palavra apareceu.  
count_vectors1 = vectors1.fit_transform(corpus)
print("\nvocabulario 1: ",vectors1.vocabulary_)
print("\nshape do vocabulario 1:1 ",count_vectors1.shape)
# Out:
# vocabulario 1:  {'tremores': 11349, 'de': 3072, 'terra': 11056, 'na': 7747, 'república': 9918, 'democrática': 3201, 'do': 3755, 'congo': 2525, 'nesta': 7859, 'segundafeira': 10404, 'moradores': 7567, 'novo': 7964, 'presidente': 9023, 'equador': 4243, 'guillermo': 5614, 'lasso': 6675, 'foi': 5128, 'empossado': 4054, 'em': 4012, 'capital': 1804, 'quito': 9515, 'cerimô': 1977, 'novos': 7965, 'dados': 3034, 'sobre': 10636, 'pesquisadores': 8631, 'wuhan': 12002, 'aumentam': 1126, 'debate': 3074, 'origens': 8193, 'da': 3031, 'covid': 2842, 'rt': 10192, 'ericsson': 4263, 'disse': 3679, 'que': 9454, 'pode': 8755, 'obter': 8022, 'uma': 11502, 'fatia': 4881, 'menor': 7326, 'no': 7905, 'lançamento': 6658, 'china': 2066, 'sua': 10752, 'participação': 8384, 'mercado': 7347, 'aeroportos': 257, 'devem': 3504, 'ser': 10494, 'foco': 5121, 'para': 8319, 'conter': 2656, 'variante': 11643, 'índia': 12082, 'diz': 3739, 'infectologista': 6107, 'voltado': 11902, 'os': 8204, 'pequenos': 8537, 'negócios': 7840, 'microcrédito': 7396, 'um': 11501, 'tipo': 11132, 'empréstimo': 4076, 'oferece': 8066, 'vantagens': 11631, 'outros': 8220, 'não': 7978, 'têm': 11465, 'creditas': 2862, 'resolveu': 9945, 'fazer': 4908, 'grande': 5531, 'aposta': 755, 'fora': 5142, 'área': 12063, 'produtos': 9158, 'financeiros': 5052, 'milhões': 7412, 'fabrica': 4786, 'banco': 1266, 'coreia': 2769, 'sul': 10791, 'informou': 6135, 'busca': 1635, 'empresa': 4067, 'tecnologia': 10965, 'desenvolver': 3358, 'seu': 10532, 'projeto': 9194, 'moeda': 7525, 'digital': 3565, 'ht': 5777, 'quartafeira': 9448, 'das': 3062, 'criptomoedas': 2906, 'cerca': 1973, 'us': 11547, 'trilhão': 11370, 'valor': 11623, 'queda': 9460, 'petrobras': 8649, 'anunciou': 680, 'programa': 9183, 'prevê': 9080, 'investimentos': 6335, 'até': 1110, 'pessoas': 8642, 'físicas': 5319, 'podem': 8756, 'doar': 3759, 'dos': 3810, 'impostos': 5945, 'dinheiro': 3582, 'devido': 3513, 'fundos': 5286, 'sociais': 10647, 'diamante': 3534, 'impecável': 5912, 'alcança': 389, 'recorde':
': 547, 'já': 6574, 'vacinaram': 11592, 'população': 8814, 'contra': 2678, 'pazuello': 8462, 'entendeu': 4168, 'cometeu': 2310, 'erro': 4272, 'mourão': 7624, 'ato': 1064, 'rio': 10093, 'apoiadores': 736, 'ouvidos': 8225, 'pela': 8503, 'cnn': 2195, 'afirmam': 282, 'militar': 7421, 'tem': 10988, 'sido': 10557, 'concorrer': 2458, 'pa': 8239, 'pouso': 8892, 'sequestro': 10491, 'apoiado': 734, 'governo': 5517, 'belarus': 1351, 'regata': 9752, 'atrai': 1069, 'centenas': 1957, 'veneza': 11704, 'mentiu': 7343, 'muito': 7659, 'será': 10519, 'reconvocado': 9665, 'cpi': 2851, 'pandemia': 8301, 'omar': 8111, 'aziz': 1214, 'entrevista': 4201, 'tomaram': 11179, 'as': 918, 'águas': 12054, 'comemorou': 2295, 'aniversário': 617, 'cidade': 2106, 'bolsonaro': 1502, 'está': 4527, 'acompanhar': 148, 'quadro': 9423, 'poder': 8758, 'rádio': 10215, 'william': 11987, 'waack': 11961, 'fala': 4809, 'quarta': 9445, 'semana': 10439, 'depoimentos': 3242, 'senadores': 10460, 'compõem': 2418, 'vão': 11948, 'dedicar': 3118, 'único': 12105, 'dia': 3524, 'analisar': 580, 'votar': 11927, 'todos': 11167, 're': 9569, 'brasileira': 1567, 'primeira': 9088, 'latina': 6680, 'negra': 7834, 'escalar': 4282, 'everest': 4570, 'reação': 9605, 'jair': 6434, 'deve': 3502, 'reforçar': 9745, ...
#
# shape do vocabulario 2:  (16240, 12108)

# %%
### Ignorar palavras que aparecem muito - acima de 50% dos documentos
### alta frequência + baixa frequência + ngrams --> , ngram_range(3,4) ?

vectors3 = CountVectorizer(min_df = 2, max_df = 0.5, ngram_range=(3,4))
count_vectors3 = vectors3.fit_transform(corpus)
print("\nvocabulario 3: ",vectors3.vocabulary_)
print("\nshape do vocabulario 3: ",count_vectors3.shape)
# Out:
# vocabulario 3:  {'na república democrática': 20161, 'república democrática do': 27472, 'democrática do congo': 9959, 'na república democrática do': 20162, 'república democrática do congo': 27473, 'novo presidente do': 21474, 'presidente do equador': 25128, 'do equador guillermo': 11182, 'equador guillermo lasso': 13535, 'guillermo lasso foi': 16050, 'lasso foi empossado': 17492, 'foi empossado nesta': 15141, 'empossado nesta segundafeira': 13198, 'nesta segundafeira em': 20467, 'segundafeira em na': 28891, 'em na capital': 12803, 'na capital quito': 19899, 'capital quito cerimô': 3614, 'novo presidente do equador': 21475, 'presidente do equador guillermo': 25129, 'do equador guillermo lasso': 11183, 'equador guillermo lasso foi': 13536, 'guillermo lasso foi empossado': 16051, 'lasso foi empossado nesta': 17493, 'foi empossado nesta segundafeira': 15142, 'empossado nesta segundafeira em': 13199, 'nesta segundafeira em na': 20468, 'segundafeira em na capital': 28892, 'em na capital quito': 12804, 'na capital quito cerimô': 19900, 'sobre origens da': 29663, 'origens da covid': 22084, 'sobre origens da covid': 29664, 'no lançamento de': 
### alta frequência + baixa frequência + numero de palavras

vectors4 = CountVectorizer(min_df = 2, max_df = 0.5, max_features = 1000)
count_vectors4 = vectors4.fit_transform(corpus)
print("\nvocabulario 4: ",vectors4.vocabulary_)
print("\nshape do vocabulario 4: ",count_vectors4.shape)
# Out:
# vocabulario 4:  {'terra': 904, 'na': 588, 'república': 810, 'do': 252, 'nesta': 597, 'segundafeira': 838, 'novo': 622, 'presidente': 731, 'foi': 371, 'em': 281, 'capital': 119, 'novos': 623, 'dados': 202, 'sobre': 870, 'pesquisadores': 694, 'debate': 207, 'da': 201, 'covid': 191, 'rt': 821, 'disse': 246, 'que': 774, 'pode': 709, 'uma': 942, 'menor': 542, 'no': 609, 'china': 139, 'sua': 877, 'participação': 666, 'mercado': 544, 'devem': 231, 'ser': 852, 'para': 660, 'variante': 962, 'índia': 994, 'diz': 248, 'os': 644, 'um': 941, 'outros': 648, 'não': 627, 'têm': 938, 'fazer': 351, 'grande': 403, 'fora': 374, 'área': 993, 'milhões': 552, 'banco': 85, 'sul': 880, 'busca': 110, 'empresa': 284, 'tecnologia': 895, 'seu': 858, 'projeto': 749, 'digital': 238, 'quartafeira': 771, 'das': 205, 'cerca': 134, 'us': 947, 'valor': 960, 'queda': 776, 'petrobras': 697, 'anunciou': 40, 'programa': 748, 'prevê': 735, 'investimentos': 452, 'até': 73, 'pessoas': 696, 'podem': 710, 'dos': 258, 'dinheiro': 239, 'sociais': 871, 'recorde': 790, 'comissão': 160, 'reforma': 797, 'por': 720, 'como': 161, 'paulista': 672, 'registrou': 799, 'nas': 591, 'horas': 421, 'desta': 225, 'segundo': 839, 'causa': 130, 'com': 155, 'deixou': 215, 'mortos': 566, 'mais': 516, 'últimos': 999, 'anos': 37, 'casa': 127, 'papel': 659, 'ao': 43, 'fim': 365, 'ainda': 18, 'estados': 309, 'já': 474, 'população': 719, 'contra': 178, 'pazuello': 675, 'ato': 67, 'rio': 817, 'pela': 685, 'cnn': 150, 'militar': 553, 'tem': 896, 'sido': 863, 'pa': 651, 'governo': 402, 'muito': 574, 'será': 854, 'cpi': 192, 'pandemia': 658, 'omar': 633, 'aziz': 80, 'entrevista': 294, 'as': 60, 'cidade': 141, 'bolsonaro': 100, 'está': 320, 'quadro': 763, 'poder': 711, 'william': 990, 'waack': 987, 'fala': 340, 'quarta': 770, 'semana': 845, 'depoimentos': 220, 'senadores': 850, 'vão': 982, 'dia': 234, 'todos': 917, 'brasileira': 104, 'primeira': 738, 'jair': 459, 'deve': 230, 'podcast': 708, 'eu': 322, 'fernando': 354, 'alexandre': 21, 'empresas': 285, 'manter': 523, 'trabalho': 922, 'pesquisa': 693, 'aponta': 50, 'se': 832, 'inflação': 439, 'país': 676, 'isso': 457, 'ano': 36, 'passado': 670, 'comércio': 167, 'levantamento': 485, 'alta': 24, 'após': 54, 'recuperação': 792, 'edição': 270, 'médico': 583, 'gomes': 399, 'morte': 564, 'vacinação': 957, 'profissionais': 747, 'possível': 722, 'janeiro': 460, 'liberdade': 489, 'opinião': 640, 'manifestação': 522, 'favor': 348, 'número': 629, 'mortes': 565, 'entre': 292, 'fez': 357, 'série': 888, 'você': 978, 'parte': 665, 'estava': 315, 'grupo': 407, 'líder': 508, 'qual': 765, 'afirmou': 15, 'bilhões': 93, 'foram': 375, 'fiocruz': 368, 'produção': 745, 'vacina': 953, 'amanhã': 28, 'exministro': 331, 'saúde': 831, 'eduardo': 272, 'general': 391, 'ministro': 556, 'pede': 679, 'nem': 596, 'sempre': 847, 'precisa': 727, 'abrir': 5, 'ou': 645, 'seus': 859, 'serviços': 853, 'federal': 352, 'libera': 488, 'primeiro': 739, 'lote': 501, 'imposto': 432, 'renda': 808, 'senador': 849, 'secretário': 835, 'são': 885, 'paulo': 673, 'autoridades': 76, 'coronavírus': 185, 'deputados': 223, 'pelo': 687, 'menos': 543, 'casos': 129, 'negro': 594, 'acordo': 12, 'neste': 598, 'episódio': 295, 'sociedade': 873, 'outras': 646, 'evitar': 326, 'espera': 304, 'leitos': 483, 'segurança': 840, 'mil': 550, 'movimento': 569, 'estado': 308, 'depois': 221, 'medida': 536, 'mc': 534, 'kevin': 475, 'teve': 910, 'sendo': 851, 'vacinas': 956, 'vacinar': 955, 'mas': 531, 'apenas': 45, 'secretaria': 833, 'situação': 868, 'tratamento': 924, 'mês': 585, 'maio': 512, 'eua': 323, 'biden': 92, 'família': 344, 'terçafeira': 907, 'feito': 353, 'brasil': 103, 'estão': 321, 'falta': 343, 'entrega': 293, 'caixa': 115, 'segunda': 837, 'auxílio': 77, 'emergencial': 283, 'bolsa': 97, 'relações': 805, 'pediu': 683, 'todas': 915, 'prefeitura': 729, 'esta': 307, 'plano': 704, 'ação': 81, 'caso': 128, 'seja': 842, 'maior': 513, 'doses': 260, 'desde': 224, 'rússia': 824, 'avião': 79, 'domingo': 256, 'exército': 336, ...
#
# shape do vocabulario 4:  (16240, 1000)

# %% [markdown]
# **- Retira palavras iguais a pronomes, preposição, artigos definidos e indefinidos**

# %%
### A princípio é necessário de um dicionário que já tenha esse conjunto de palavras ou utilizar a NLTK que possui alguns
from nltk.corpus import stopwords
import nltk

nltk.download('stopwords')
language = "portuguese"

print(stopwords.words(language))

for word in stopwords.words(language):
    print (word)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um', 'para', 'com', 'não', 'uma', 'os', 'no', 'se', 'na', 'por', 'mais', 'as', 'dos', 'como', 'mas', 'ao', 'ele', 'das', 'à', 'seu', 'sua', 'ou', 'quando', 'muito', 'nos', 'já', 'eu', 'também', 'só', 'pelo', 'pela', 'até', 'isso', 'ela', 'entre', 'depois', 'sem', 'mesmo', 'aos', 'seus', 'quem', 'nas', 'me', 'esse', 'eles', 'você', 'essa', 'num', 'nem', 'suas', 'meu', 'às', 'minha', 'numa', 'pelos', 'elas', 'qual', 'nós', 'lhe', 'deles', 'essas', 'esses', 'pelas', 'este', 'dele', 'tu', 'te', 'vocês', 'vos', 'lhes', 'meus', 'minhas', 'teu', 'tua', 'teus', 'tuas', 'nosso', 'nossa', 'nossos', 'nossas', 'dela', 'delas', 'esta', 'estes', 'estas', 'aquele', 'aquela', 'aqueles', 'aquelas', 'isto', 'aquilo', 'estou', 'está', 'estamos', 'estão', 'estive', 'esteve', 'estivemos', 'estiveram', 'estava', 'estávamos', 'estavam', 'estivera', 'estivéramos', 'esteja', 'estejamos', 'estejam', 'estivesse', 'estivéssemos', 'estivessem', 'estiver', 'estivermos', 'estiverem', 'hei', 'há', 'havemos', 'hão', 'houve', 'houvemos', 'houveram', 'houvera', 'houvéramos', 'haja', 'hajamos', 'hajam', 'houvesse', 'houvéssemos', 'houvessem', 'houver', 'houvermos', 'houverem', 'houverei', 'houverá', 'houveremos', 'houverão', 'houveria', 'houveríamos', 'houveriam', 'sou', 'somos', 'são', 'era', 'éramos', 'eram', 'fui', 'foi', 'fomos', 'foram', 'fora', 'fôramos', 'seja', 'sejamos', 'sejam', 'fosse', 'fôssemos', 'fossem', 'for', 'formos', 'forem', 'serei', 'será', 'seremos', 'serão', 'seria', 'seríamos', 'seriam', 'tenho', 'tem', 'temos', 'tém', 'tinha', 'tínhamos', 'tinham', 'tive', 'teve', 'tivemos', 'tiveram', 'tivera', 'tivéramos', 'tenha', 'tenhamos', 'tenham', 'tivesse', 'tivéssemos', 'tivessem', 'tiver', 'tivermos', 'tiverem', 'terei', 'terá', 'teremos', 'terão', 'teria', 'teríamos', 'teriam']
# de
# a
# o
# que
# e
# é
# do
# da
# em
# um
# para
# com
# não
# uma
# os
# no
# se
# na
# por
# mais
# as
# dos
# como
# mas
# ao
# ele
# das
# à
# seu
# sua
# ou
# quando
# muito
# nos
# já
# eu
# também
# só
# pelo
# pela
# até
# isso
# ela
# entre
# depois
# sem
# mesmo
# aos
# seus
# quem
# nas
# me
# esse
# eles
# você
# essa
# num
# nem
# suas
# meu
# às
# minha
# numa
# pelos
# elas
# qual
# nós
# lhe
# deles
# essas
# esses
# pelas
# este
# dele
# tu
# te
# vocês
# vos
# lhes
# meus
# minhas
# teu
# tua
# teus
# tuas
# nosso
# nossa
# nossos
# nossas
# dela
# delas
# esta
# estes
# estas
# aquele
# aquela
# aqueles
# aquelas
# isto
# aquilo
# estou
# está
# estamos
# estão
# estive
# esteve
# estivemos
# estiveram
# estava
# estávamos
# estavam
# estivera
# estivéramos
# esteja
# estejamos
# estejam
# estivesse
# estivéssemos
# estivessem
# estiver
# estivermos
# estiverem
# hei
# há
# havemos
# hão
# houve
# houvemos
# houveram
# houvera
# houvéramos
# haja
# hajamos
# hajam
# houvesse
# houvéssemos
# houvessem
# houver
# houvermos
# houverem
# houverei
# houverá
# houveremos
# houverão
# houveria
# houveríamos
# houveriam
# sou
# somos
# são
# era
# éramos
# eram
# fui
# foi
# fomos
# foram
# fora
# fôramos
# seja
# sejamos
# sejam
# fosse
# fôssemos
# fossem
# for
# formos
# forem
# serei
# será
# seremos
# serão
# seria
# seríamos
# seriam
# tenho
# tem
# temos
# tém
# tinha
# tínhamos
# tinham
# tive
# teve
# tivemos
# tiveram
# tivera
# tivéramos
# tenha
# tenhamos
# tenham
# tivesse
# tivéssemos
# tivessem
# tiver
# tivermos
# tiverem
# terei
# terá
# teremos
# terão
# teria
# teríamos
# teriam

# %%
stopwords_list  = stopwords.words(language)
vectors5        = CountVectorizer(stop_words=stopwords_list)
count_vectors5  = vectors5.fit_transform(corpus)
print(vectors5.vocabulary_)
print(count_vectors5.shape)
# Out:
# {'tremores': 21886, 'terra': 21355, 'sacudiram': 19796, 'goma': 10619, 'república': 19130, 'democrática': 6217, 'congo': 4924, 'nesta': 15209, 'segundafeira': 20088, 'assustando': 1900, 'moradores': 14673, 'novo': 15414, 'presidente': 17417, 'equador': 8274, 'guillermo': 10851, 'lasso': 12986, 'empossado': 7880, 'capital': 3536, 'quito': 18283, 'cerimô': 3902, 'novos': 15415, 'dados': 5895, 'sobre': 20502, 'pesquisadores': 16700, 'wuhan': 23094, 'aumentam': 2139, 'debate': 5981, 'origens': 15851, 'covid': 5530, 'rt': 19698, 'ericsson': 8306, 'disse': 7184, 'pode': 16954, 'obter': 15533, 'fatia': 9456, 'menor': 14215, 'lançamento': 12957, 'china': 4048, 'participação': 16218, 'mercado': 14251, 'infra': 11887, 'aeroportos': 489, 'devem': 6875, 'ser': 20230, 'foco': 9895, 'conter': 5144, 'variante': 22416, 'índia': 23274, 'diz': 7284, 'infectologista': 11824, 'voltado': 22894, 'pequenos': 16507, 'negócios': 15181, 'microcrédito': 14352, 'tipo': 21489, 'empréstimo': 7913, 'oferece': 15617, 'vantagens': 22396, 'outros': 15909, 'têm': 22105, 'creditas': 5569, 'resolveu': 19196, 'fazer': 9501, 'grande': 10710, 'aposta': 1466, 'área': 23233, 'produtos': 17639, 'financeiros': 9752, 'injetando': 11937, 'milhões': 14395, 'fabrica': 9281, 'banco': 2433, 'co
# (16240, 23317)

# %% [markdown]
# # **4. Preparação dos dados**

# %% [markdown]
# ## **4.1 Classificação dos textos**

# %%
#### Classificando os tweets em 3 categorias determinadas pelo número de likes

tsh1 = 32.00000 + 150.546769
tsh2 = 32.00000

# %%
df_copy['likes_faixa'] = df_copy['likes'].apply(lambda x: 1 if (x > tsh1)
                                                    else (0 if (x > tsh2)
                                                    else -1))

# %%
df_copy
# Out:
#                         id           created_at  ... retweeted  likes_faixa
# 0      1396860868957130755  2021-05-24 16:09:18  ...     False           -1
# 1      1396860373601427460  2021-05-24 16:07:20  ...     False           -1
# 2      1396860123868446720  2021-05-24 16:06:20  ...     False            0
# 3      1396860068935749632  2021-05-24 16:06:07  ...     False           -1
# 4      1396858874125295617  2021-05-24 16:01:22  ...     False            0
# ...                    ...                  ...  ...       ...          ...
# 16235  1343270711117414400  2020-12-27 19:01:08  ...     False           -1
# 16236  1343255583504412672  2020-12-27 18:01:02  ...     False           -1
# 16237  1343240634199638017  2020-12-27 17:01:38  ...     False           -1
# 16238  1343225525003808768  2020-12-27 16:01:35  ...     False            0
# 16239  1343210172970360838  2020-12-27 15:00:35  ...     False            0
#
# [16240 rows x 7 columns]

# %%
### Usando OneHotEnconder para melhorar a classificação dos modelos de Machine Learning
from sklearn.preprocessing import OneHotEncoder

df_ohc = df_copy[['retweeted']]

#Criando meu encoder
enc = OneHotEncoder(handle_unknown='ignore', sparse=False)
enc.fit(df_ohc)

# Transformando texto em numero
XX_text = enc.transform(df_ohc)

# Criando DataFrame texto -> numerico
df_ohc = pd.DataFrame(XX_text, columns=enc.get_feature_names(df_ohc.columns))

# %%
df_ohc      #Não é necessário utilizar uma vez que só há uma categoria
# Out:
#        retweeted_False
# 0                  1.0
# 1                  1.0
# 2                  1.0
# 3                  1.0
# 4                  1.0
# ...                ...
# 16235              1.0
# 16236              1.0
# 16237              1.0
# 16238              1.0
# 16239              1.0
#
# [16240 rows x 1 columns]

# %%
df_final = df_copy[['text', 'likes_faixa']]

# %%
df_final
# Out:
#                                                     text  likes_faixa
# 0      Tremores de terra sacudiram Goma na República ...           -1
# 1      O novo presidente do Equador Guillermo Lasso f...           -1
# 2      Novos dados sobre pesquisadores de Wuhan aumen...            0
# 3      RT  A Ericsson disse que pode obter uma fatia ...           -1
# 4      Aeroportos devem ser foco para conter a varian...            0
# ...                                                  ...          ...
# 16235  Este conteúdo faz parte da NexoEDUnoEnem  noss...           -1
# 16236  AcessoLivre   Ao longo do mês de dezembro o Ne...           -1
# 16237  Este conteúdo faz parte da NexoEDUnoEnem  noss...           -1
# 16238  opinião O termo empreendedorismo nada mais é d...            0
# 16239  Seleção MaisLidasDoNexo entre os assinantes em...            0
#
# [16240 rows x 2 columns]

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Estágio - IMT & NPL Brasil/Notebooks'
df_final.to_csv(os.path.join(path,r'DataFrame_final_Twitter.csv'), index=False)
